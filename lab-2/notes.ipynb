# %% [markdown]
# ### Prelab
#
# #### Task 1
# I need to make a function that gets
# - x input to make a sin aprroximation of
# - n input that chooses accurary. n needs to be 2n+1
# ![Screenshot 2026-09-21 at 11.15.41 AM.png](<attachment:Screenshot 2026-09-21 at 11.15.41 AM.png>)

# %%
#include <stdio.h>
#include <math.h> // for pow()

double fact(int n) { 
    
    // Negative input condition
    if (n < 0) { // factorial is undefined
        return -1.0;
    }
    
    // zero input condition
    else if (n == 0) {
    
    // factorial is 1
        return 1;
    }
    // standard factorial computation
    else {
        double factorial = 1.0;
        for (int i = 1; i <= n; i++) {
            factorial *= i;
        }
    return factorial;
    }
}

double getSinApprox(double x, int terms) {
    double result;
    for (int j = 0; j <= terms; j++) {
        int f = fact(2*j+1);
        result = ((pow(-1.0, j)*pow(x, (2*j+1)))/f);
        printf("\n%d", f);
        printf("\n%lf", result);
    }
    return result;
}

int main() { // take number input and get power series
    double x_input;
    int n_input;

    printf("\nGive me X in degrees: ");
    scanf("%lf", &x_input);
    printf("\nGive me N: ");
    scanf("%d", &n_input);

    double ans = getSinApprox(((x_input/180.0)*3.14), n_input);
    printf("\nAnswer is: %lf \n", ans);
}

# %% [markdown]
# What I got wrong:
# - result in getSinApprox() wasn't adding to itself, it was just overridding.
# - I was storing the output of fact (which is a double) inside an int, therefore truncating it.
# - in getSinApprox() it should just be j < terms not j<= terms
