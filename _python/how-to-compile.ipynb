# %% [markdown]
# ### Windows
# Compile:

# %%
cl YourFile.cpp

# %% [markdown]
# Run:

# %%
.\YourFile.exe

# %% [markdown]
# ### Mac
# Compile:

# %%
gcc YourFile.cpp -o YourFile

# %% [markdown]
# Run:

# %%
./YourFile
