# %% [markdown]
# ## Pre-Lab 1
#
# ### Write a program to convert temperature
# Program needs to conver temp in C to degree F with the formula F=(9/5)C + 32. Celcius value as the input from the user and print out the Fahrenheit value to the screen.

# %% [markdown]
# **Here's my first go:** (all by me, no ai)

# %% [raw]
# #include <iostream>
#
# //Declare vars
# float temp_c;
# float temp_f;
#
# float convert_to_f(float c){
#     f = (9/5)*c + 32;
#     return f;
# }
#
# void main() {
#     printf("\nHi! Please enter a temperature in degrees Celcius:");
#     scanf_s("%f", &temp_c);
#     temp_f = convert_to_f(temp_c);
#     printf("\nTemperature in F: %f", temp_f);
# }

# %% [markdown]
# Here's what I missed (looked at by Claude):
# - "f" is never declared inside convert_to_f
# - Need #include cstdio to use printf and scanf_s. (some compilers let it slide by it not guaranteed and is bad practice)
# - scanf_s is a Microsoft specific (non-standard) function. It wont compile on Linux and Mac. This particular call is fine syntatically on MSVC but it's not portable
#
# Here's what *will compile* but is bad practice"
# - void main() is not standard C++, it should be **int main()**. Some compilers like older MSVC accept it, but its technically invalid.
# - iostream does pull cstdio as its own internal header when compiled with MSVC. But it could fail when compiled on GCC/Clang/MinGW. So its best practice to include explictly cstdio as mentioned above to use the printf and scanf_s functions.
# - Integer division bug: (9/5) evals to 1 in integer arithmetic. 9/5 = 1.8 is ***truncated*** to 1.
#     - Fix: need to do (9.0f/5.0f)
#
#
# #### Compiling (Windows with MSVC)
# **This doc was used to setup MSVC compiler**:
# https://code.visualstudio.com/docs/cpp/config-msvc
#
# To compile the .cpp file:

# %% [raw]
# cl YourFile.cpp

# %% [markdown]
# To run the .cpp file:

# %% [raw]
# .\YourFile.exe

# %% [markdown]
# #### Compiling (Mac with Clang)
#
# To compile the .cpp file:

# %%
gcc YourFile.cpp -o YourFile

# %% [markdown]
# To run the .cpp file:

# %%
./YourFile

# %% [markdown]
# ### Sort an Array
#
# Here's the program I made to sort an array. Note you need to cycle through the array to print it in the terminal element by element.

# %% [raw]
# #include <cstdio> // for printf and scanf
#
# int main()
# {
#     int numbers[10] = {9, 4, 5, 2, 3, 0, 8, 1, 7, 6};
#     int val;
#
#     printf("Here's the array that will be sorted:");
#
#     // loop thru all values in numbers array
#     for (int m = 0; m < 10; m++)
#     {
#         printf("%d ", numbers[m]);
#     }
#
#     printf("\nThese will now be sorted...");
#
#     for (int i = 0; i < 10; i++)
#     {
#         for (int j = i + 1; j < 10; j++) // had to change from j=1 to j=i+1 and j<i to j<10.
#         {
#             if (numbers[j] < numbers[i]) {
#                 val = numbers[i];
#                 numbers[i] = numbers[j];
#                 numbers[j] = val;
#             }
#         }
#     }
#
#     printf("\nHere's the sorted array:");
#
#     for (int n = 0; n < 10; n++)
#     {
#         printf("%d ", numbers[n]); //added a space after %d so each number would seperate
#     }
# }

# %% [markdown]
# ### Adding Hex Program
# Here's my first go at the adding program (no ai):

# %%
// Program to check addition of hexadecimal numbers
#include <cstdio>

int main() {
    int augend;
    int addend;
    scanf("\nInput the augend in hex: %d", &augend);
    scanf("\nInput the addend in hex: %d", &addend);
    int sum = augend + addend;
    printf("Sum: %d", sum);
}

# %% [markdown]
# #### Issues:
# - code compiles, but when its ran the prgram just hangs indefinitely.
#     - this was due to the scanf function and package call. On Mac, I need to use sdtio to get printf and scanf. scanf_s doesn't exist without MSVC.
#
# #### Fixed code:

# %%
// Program to check addition of hexadecimal numbers
#include <stdio.h> // need stdio
//#include <cstdio> this should work on windows I think

int main() {

    //declares 
    int augend;
    int addend;
    int sum;
    printf("\nInput the augend in hex: ");
    scanf("%x", &augend); // use %x for hex, not %d

    printf("\nInput the addend in hex: ");
    scanf("%x", &addend);

    sum = augend + addend;
    printf("Sum (hex): %x\n", sum);
    printf("Sum (dec): %d\n", sum);
}

# %% [markdown]
# #### NOTE
# To run this one on windows, include the following at the top to supress the warnings:
# - MSVC prefers to use its own printf_s and scanf_s so it will throw a warning.

# %%
#define _CRT_SECURE_NO_WARNINGS
